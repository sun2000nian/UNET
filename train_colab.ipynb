# %%
import tensorflow as tf
from model import unet
from data_colab import getData
from matplotlib import pyplot as plt
import numpy as np
import imageio

# %%
# !git clone https://github.com/sun2000nian/UNET.git

# %%
imgs, labels = getData()
print(imgs.shape,labels.shape)
plt.imshow(tf.concat([imgs[0]/255.0,labels[0]/255.0],axis=1))
# Out:
# (30, 128, 128, 1) (30, 128, 128, 1)

# %%
tf.reduce_max(imgs),tf.reduce_max(labels)
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=255.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=255.0>)

# %%
model=unet(input_size=(128,128,1))

# %%
history=model.fit(x=imgs,y=labels,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 36s 36s/step - loss: -28415.5039 - accuracy: 2.7059e-04
# Epoch 2/10
# 1/1 [==============================] - 31s 31s/step - loss: -232372.0000 - accuracy: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 32s 32s/step - loss: -1335728.3750 - accuracy: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 31s 31s/step - loss: -5315934.0000 - accuracy: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 32s 32s/step - loss: -18235524.0000 - accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 31s 31s/step - loss: -55669900.0000 - accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 32s 32s/step - loss: -159672640.0000 - accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 32s 32s/step - loss: -438250112.0000 - accuracy: 0.0000e+00
# Epoch 9/10
# ...

# %%
result=model.predict(imgs)
plt.imshow(result[0])
